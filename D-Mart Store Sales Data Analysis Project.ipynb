# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\kavan\OneDrive\Desktop\DMart Data Store.csv")

# %%
df.shape
# Out:
# (8047, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8047 entries, 0 to 8046
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       8047 non-null   object
#  1   Order Date     8047 non-null   object
#  2   Customer Name  8047 non-null   object
#  3   Country        8047 non-null   object
#  4   State          8047 non-null   object
#  5   City           8047 non-null   object
#  6   Region         8047 non-null   object
#  7   Segment        8047 non-null   object
#  8   Ship Mode      8047 non-null   object
#  9   Category       8047 non-null   object
#  10  Sub-Category   8047 non-null   object
#  11  Product Name   8047 non-null   object
#  12   Discount      8047 non-null   object
#  13   Sales         8047 non-null   object
#  14   Profit        8047 non-null   object
#  15  Quantity       8047 non-null   int64
#  16  Feedback?      8047 non-null   bool
# ...

# %%
df.head()
# Out:
#           Order ID  Order Date     Customer Name         Country  \
# 0  BN-2011-7407039  01-01-2011        Ruby Patel          Sweden
# 1  AZ-2011-9050313  03-01-2011    Summer Hayward  United Kingdom
# 2  AZ-2011-6674300  04-01-2011  Devin Huddleston          France
# 3  BN-2011-2819714  04-01-2011       Mary Parker  United Kingdom
# 4  BN-2011-2819714  04-01-2011       Mary Parker  United Kingdom
#
#                   State        City   Region      Segment     Ship Mode  \
# 0             Stockholm   Stockholm    North  Home Office  Economy Plus
# 1               England   Southport    North     Consumer       Economy
# 2  Auvergne-Rhône-Alpes     Valence  Central     Consumer       Economy
# 3               England  Birmingham    North    Corporate       Economy
# 4               England  Birmingham    North    Corporate       Economy
#
#           Category Sub-Category                           Product Name  \
# ...

# %%
df['Quantity'].unique()
# Out:
# array([ 3,  7,  2,  4,  1,  6,  5, 11,  8, 10, 12,  9, 14, 13],
#       dtype=int64)

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8042    False
# 8043    False
# 8044    False
# 8045    False
# 8046    False
# Length: 8047, dtype: bool

# %%
df.loc[df.duplicated(), :]
# Out:
#              Order ID  Order Date      Customer Name  Country    State  \
# 2543  AZ-2012-5907386  29-08-2012       Louie Knight  Belgium  Antwerp
# 4066  AZ-2013-5637964  14-06-2013  Cynthia Zielinski    Spain   Madrid
#
#           City   Region      Segment Ship Mode         Category Sub-Category  \
# 2543  Mechelen  Central     Consumer   Economy  Office Supplies          Art
# 4066    Madrid    South  Home Office   Economy  Office Supplies      Binders
#
#                             Product Name  Discount   Sales   Profit   \
# 2543           Sanford Pens, Fluorescent      $-       $37      $10
# 4066  Wilson Jones 3-Hole Punch, Economy      $-       $84      $28
#
#       Quantity  Feedback?
# 2543         3      False
# 4066         3       True

# %%
df.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Customer Name    0
# Country          0
# State            0
# City             0
# Region           0
# Segment          0
# Ship Mode        0
# Category         0
# Sub-Category     0
# Product Name     0
#  Discount        0
#  Sales           0
#  Profit          0
# Quantity         0
# Feedback?        0
# dtype: int64

# %%
df.head()
# Out:
#           Order ID  Order Date     Customer Name         Country  \
# 0  BN-2011-7407039  01-01-2011        Ruby Patel          Sweden
# 1  AZ-2011-9050313  03-01-2011    Summer Hayward  United Kingdom
# 2  AZ-2011-6674300  04-01-2011  Devin Huddleston          France
# 3  BN-2011-2819714  04-01-2011       Mary Parker  United Kingdom
# 4  BN-2011-2819714  04-01-2011       Mary Parker  United Kingdom
#
#                   State        City   Region      Segment     Ship Mode  \
# 0             Stockholm   Stockholm    North  Home Office  Economy Plus
# 1               England   Southport    North     Consumer       Economy
# 2  Auvergne-Rhône-Alpes     Valence  Central     Consumer       Economy
# 3               England  Birmingham    North    Corporate       Economy
# 4               England  Birmingham    North    Corporate       Economy
#
#           Category Sub-Category                           Product Name  \
# ...

# %%
df.describe()
# Out:
#           Quantity
# count  8047.000000
# mean      3.772089
# std       2.203369
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       5.000000
# max      14.000000

# %%
df['Sales'] = df['Sales'].str.replace('\$', '', regex=True)

# %%
df['Discount'] = df['Discount'].str.replace('\$', '', regex=True)

# %%
df['Profit'] = df['Profit'].str.replace('\$', '', regex=True)

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Customer Name', 'Country', 'State', 'City',
#        'Region', 'Segment', 'Ship Mode', 'Category', 'Sub-Category',
#        'Product Name', 'Discount', 'Sales', 'Profit', 'Quantity', 'Feedback?'],
#       dtype='object')

# %%
df.head()
# Out:
#           Order ID  Order Date     Customer Name         Country  \
# 0  BN-2011-7407039  01-01-2011        Ruby Patel          Sweden
# 1  AZ-2011-9050313  03-01-2011    Summer Hayward  United Kingdom
# 2  AZ-2011-6674300  04-01-2011  Devin Huddleston          France
# 3  BN-2011-2819714  04-01-2011       Mary Parker  United Kingdom
# 4  BN-2011-2819714  04-01-2011       Mary Parker  United Kingdom
#
#                   State        City   Region      Segment     Ship Mode  \
# 0             Stockholm   Stockholm    North  Home Office  Economy Plus
# 1               England   Southport    North     Consumer       Economy
# 2  Auvergne-Rhône-Alpes     Valence  Central     Consumer       Economy
# 3               England  Birmingham    North    Corporate       Economy
# 4               England  Birmingham    North    Corporate       Economy
#
#           Category Sub-Category                           Product Name  \
# ...

# %%
df = df.rename(columns={' Sales ': 'Sales'})

# %%
df = df.rename(columns={' Discount ': 'Discount'})

# %%
df = df.rename(columns={' Profit ': 'Profit'})

# %%
df['Sales'] = pd.to_numeric(df['Sales'], errors='coerce')

# %%
df['Discount'] = pd.to_numeric(df['Discount'], errors='coerce')

# %%
df['Profit'] = pd.to_numeric(df['Profit'], errors='coerce')

# %%
cols = ['Discount','Sales','Profit']

for i in cols:
    print('distribution of', i)
    plt.figure(figsize=(20,6))
    sns.boxplot(x = df[i])
    plt.show()
# Out:
# distribution of Discount
# distribution of Sales
# distribution of Profit

# %%
sns.boxplot(x = df['Sales'])
# Out:
# <Axes: xlabel='Sales'>

# %%
sns.histplot(x = df['Quantity'])
# Out:
# <Axes: xlabel='Quantity', ylabel='Count'>

# %%
df.isnull().sum()
# Out:
# Order ID            0
# Order Date          0
# Customer Name       0
# Country             0
# State               0
# City                0
# Region              0
# Segment             0
# Ship Mode           0
# Category            0
# Sub-Category        0
# Product Name        0
# Discount         4909
# Sales             525
# Profit            283
# Quantity            0
# Feedback?           0
# dtype: int64

# %%
df[df['Discount'].isnull()==True]
# Out:
#              Order ID  Order Date        Customer Name         Country  \
# 1     AZ-2011-9050313  03-01-2011       Summer Hayward  United Kingdom
# 2     AZ-2011-6674300  04-01-2011     Devin Huddleston          France
# 5      AZ-2011-617423  05-01-2011         Daniel Burke          France
# 6      AZ-2011-617423  05-01-2011         Daniel Burke          France
# 8     AZ-2011-2918397  07-01-2011   Fredrick Beveridge          France
# ...               ...         ...                  ...             ...
# 8038  AZ-2014-1412225  31-12-2014          Leon Barnes  United Kingdom
# 8040  AZ-2014-8174835  31-12-2014         Eloise Sykes         Germany
# 8041  AZ-2014-7604524  31-12-2014  Rebecca Chamberlain         Germany
# 8042   AZ-2014-766953  31-12-2014         Jose Gambino  United Kingdom
# 8046   AZ-2014-766953  31-12-2014         Jose Gambino  United Kingdom
#
#                            State              City   Region      Segment  \
# ...

# %%
df[df['Sales'].isnull()==True]
# Out:
#              Order ID  Order Date    Customer Name         Country  \
# 17    AZ-2011-7053593  11-01-2011    Gracie Powell  United Kingdom
# 117    BN-2011-307477  16-02-2011  Maya O'Sullivan          France
# 126   AZ-2011-2270958  21-02-2011    Eva Hargraves           Italy
# 140   AZ-2011-8279503  24-02-2011    Angus Reading         Belgium
# 149   AZ-2011-7903656  01-03-2011   Angus De Groot  United Kingdom
# ...               ...         ...              ...             ...
# 7993  AZ-2014-9733542  26-12-2014     Desiree Hurt         Germany
# 7994  BN-2014-2616164  27-12-2014     Carl Proctor          Sweden
# 8012  AZ-2014-6752912  29-12-2014  Lauren Saunders          France
# 8013  AZ-2014-6752912  29-12-2014  Lauren Saunders          France
# 8032  AZ-2014-3870231  30-12-2014  Thomas Thompson     Switzerland
#
#                                    State         City   Region      Segment  \
# 17                               England       Woking    North     Consumer
# ...

# %%
df[df['Profit'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [Order ID, Order Date, Customer Name, Country, State, City, Region, Segment, Ship Mode, Category, Sub-Category, Product Name, Discount, Sales, Profit, Quantity, Feedback?]
# Index: []

# %%
df['Discount'] = df['Discount'].fillna(df['Discount'].mean())
df['Sales'] = df['Sales'].fillna(df['Sales'].mean())
df['Profit'] = df['Profit'].fillna(df['Profit'].mean())

# %%
df.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Customer Name    0
# Country          0
# State            0
# City             0
# Region           0
# Segment          0
# Ship Mode        0
# Category         0
# Sub-Category     0
# Product Name     0
# Discount         0
# Sales            0
# Profit           0
# Quantity         0
# Feedback?        0
# dtype: int64

# %%
df.head()
# Out:
#           Order ID  Order Date     Customer Name         Country  \
# 0  BN-2011-7407039  01-01-2011        Ruby Patel          Sweden
# 1  AZ-2011-9050313  03-01-2011    Summer Hayward  United Kingdom
# 2  AZ-2011-6674300  04-01-2011  Devin Huddleston          France
# 3  BN-2011-2819714  04-01-2011       Mary Parker  United Kingdom
# 4  BN-2011-2819714  04-01-2011       Mary Parker  United Kingdom
#
#                   State        City   Region      Segment     Ship Mode  \
# 0             Stockholm   Stockholm    North  Home Office  Economy Plus
# 1               England   Southport    North     Consumer       Economy
# 2  Auvergne-Rhône-Alpes     Valence  Central     Consumer       Economy
# 3               England  Birmingham    North    Corporate       Economy
# 4               England  Birmingham    North    Corporate       Economy
#
#           Category Sub-Category                           Product Name  \
# ...

# %%
df.to_csv('D-Mart_Data_Assignment-6.csv', index=False)

# %%
df.describe()
# Out:
#           Discount        Sales       Profit     Quantity
# count  8047.000000  8047.000000  8047.000000  8047.000000
# mean      0.287635   189.928211    33.896960     3.772089
# std       0.117571   203.140381   130.179725     2.203369
# min       0.100000     3.000000  -993.000000     1.000000
# 25%       0.287635    48.000000     2.000000     2.000000
# 50%       0.287635   117.000000    16.000000     3.000000
# 75%       0.287635   238.000000    46.000000     5.000000
# max       0.900000   999.000000   989.000000    14.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8047 entries, 0 to 8046
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       8047 non-null   object
#  1   Order Date     8047 non-null   object
#  2   Customer Name  8047 non-null   object
#  3   Country        8047 non-null   object
#  4   State          8047 non-null   object
#  5   City           8047 non-null   object
#  6   Region         8047 non-null   object
#  7   Segment        8047 non-null   object
#  8   Ship Mode      8047 non-null   object
#  9   Category       8047 non-null   object
#  10  Sub-Category   8047 non-null   object
#  11  Product Name   8047 non-null   object
#  12  Discount       8047 non-null   float64
#  13  Sales          8047 non-null   float64
#  14  Profit         8047 non-null   float64
#  15  Quantity       8047 non-null   int64
#  16  Feedback?      8047 non-null   bool
# ...

# %%
df.corr()
# Out:
# C:\Users\kavan\AppData\Local\Temp\ipykernel_14328\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#            Discount     Sales    Profit  Quantity  Feedback?
# Discount   1.000000 -0.177527 -0.341707  0.011168   0.000739
# Sales     -0.177527  1.000000  0.164384  0.263470   0.007759
# Profit    -0.341707  0.164384  1.000000  0.113061  -0.000423
# Quantity   0.011168  0.263470  0.113061  1.000000   0.008329
# Feedback?  0.000739  0.007759 -0.000423  0.008329   1.000000

# %%
# Highest correlation
# Sales and Quantity: 0.263470
# Discount and Profit: -0.341707
