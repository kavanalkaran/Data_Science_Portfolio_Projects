# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv(r"C:\Users\kavan\OneDrive\Desktop\ev.csv")
df1.isna()
# Out:
#       Name  Subtitle  Acceleration  TopSpeed  Range  Efficiency  \
# 0    False     False         False     False  False       False
# 1    False     False         False     False  False       False
# 2    False     False         False     False  False       False
# 3    False     False         False     False  False       False
# 4    False     False         False     False  False       False
# ..     ...       ...           ...       ...    ...         ...
# 175  False     False         False     False  False       False
# 176  False     False         False     False  False       False
# 177  False     False         False     False  False       False
# 178  False     False         False     False  False       False
# 179  False     False         False     False  False       False
#
#      FastChargeSpeed  Drive  NumberofSeats  PriceinGermany  PriceinUK
# 0              False  False          False           False       True
# 1              False  False          False            True      False
# 2              False  False          False           False      False
# 3              False  False          False            True      False
# 4              False  False          False           False      False
# ..               ...    ...            ...             ...        ...
# 175            False  False          False           False       True
# 176            False  False          False           False       True
# 177            False  False          False            True      False
# 178            False  False          False           False       True
# 179            False  False          False           False       True
#
# [180 rows x 11 columns]

# %%
df1.isnull()
# Out:
#       Name  Subtitle  Acceleration  TopSpeed  Range  Efficiency  \
# 0    False     False         False     False  False       False
# 1    False     False         False     False  False       False
# 2    False     False         False     False  False       False
# 3    False     False         False     False  False       False
# 4    False     False         False     False  False       False
# ..     ...       ...           ...       ...    ...         ...
# 175  False     False         False     False  False       False
# 176  False     False         False     False  False       False
# 177  False     False         False     False  False       False
# 178  False     False         False     False  False       False
# 179  False     False         False     False  False       False
#
#      FastChargeSpeed  Drive  NumberofSeats  PriceinGermany  PriceinUK
# 0              False  False          False           False       True
# 1              False  False          False            True      False
# 2              False  False          False           False      False
# 3              False  False          False            True      False
# 4              False  False          False           False      False
# ..               ...    ...            ...             ...        ...
# 175            False  False          False           False       True
# 176            False  False          False           False       True
# 177            False  False          False            True      False
# 178            False  False          False           False       True
# 179            False  False          False           False       True
#
# [180 rows x 11 columns]

# %%
df1 = df1.fillna('0')
print(df1)
# Out:
#                                     Name  \
# 0                         Opel Ampera-e
# 1              Renault Kangoo Maxi ZE 33
# 2                           Nissan Leaf
# 3       Audi e-tron Sportback 55 quattro
# 4                 Porsche Taycan Turbo S
# ..                                   ...
# 175                         MG Marvel R
# 176  Tesla Model 3 Long Range Dual Motor
# 177                 MG MG5 EV Long Range
# 178            Audi Q4 e-tron 45 quattro
# 179          Audi Q4 Sportback e-tron 40
#
#                                       Subtitle Acceleration  TopSpeed   Range  \
# 0     Battery Electric Vehicle |       58 kWh       7.3 sec  150 km/h  335 km
# 1     Battery Electric Vehicle |       31 kWh      22.4 sec  130 km/h  160 km
# 2     Battery Electric Vehicle |       36 kWh       7.9 sec  144 km/h  220 km
# 3    Battery Electric Vehicle |       86.5 kWh      5.7 sec  200 km/h  375 km
# 4    Battery Electric Vehicle |       83.7 kWh      2.8 sec  260 km/h  390 km
# ..                                         ...          ...       ...     ...
# 175   Battery Electric Vehicle |       65 kWh       7.9 sec  200 km/h  340 km
# 176   Battery Electric Vehicle |       76 kWh       4.4 sec  233 km/h  490 km
# 177   Battery Electric Vehicle |       57 kWh       7.7 sec  185 km/h  340 km
# 178  Battery Electric Vehicle |       76.6 kWh      6.9 sec  180 km/h  385 km
# 179  Battery Electric Vehicle |       76.6 kWh      8.5 sec  160 km/h  425 km
#
#     Efficiency FastChargeSpeed              Drive  NumberofSeats  \
# 0    173 Wh/km        210 km/h  Front Wheel Drive              5
# 1    194 Wh/km               -  Front Wheel Drive              5
# 2    164 Wh/km        230 km/h  Front Wheel Drive              5
# 3    231 Wh/km        600 km/h    All Wheel Drive              5
# 4    215 Wh/km        860 km/h    All Wheel Drive              4
# ..         ...             ...                ...            ...
# 175  191 Wh/km        390 km/h   Rear Wheel Drive              5
# 176  155 Wh/km        820 km/h    All Wheel Drive              5
# 177  168 Wh/km        340 km/h  Front Wheel Drive              5
# 178  199 Wh/km        470 km/h    All Wheel Drive              5
# 179  180 Wh/km        520 km/h   Rear Wheel Drive              5
#
#     PriceinGermany PriceinUK
# 0          €42,990         0
# 1                0   £31,680
# 2          €29,990   £25,995
# 3                0   £79,900
# 4         €186,336  £138,830
# ..             ...       ...
# 175        €40,000         0
# 176        €53,560         0
# 177              0   £26,495
# 178        €50,900         0
# 179        €49,500         0
#
# [180 rows x 11 columns]

# %%
df1['Manufacturer'] = df1.Name.str.split(' ', 1, expand=True)[0]
# Out:
# C:\Users\kavan\AppData\Local\Temp\ipykernel_11296\1063087309.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['Manufacturer'] = df1.Name.str.split(' ', 1, expand=True)[0]

# %%
print(df1['Manufacturer'])
# Out:
# 0         Opel
# 1      Renault
# 2       Nissan
# 3         Audi
# 4      Porsche
#         ...
# 175         MG
# 176      Tesla
# 177         MG
# 178       Audi
# 179       Audi
# Name: Manufacturer, Length: 180, dtype: object

# %%
#cleaning the data

# %%
df1
# Out:
#                                     Name  Subtitle  Acceleration  TopSpeed  \
# 0                         Opel Ampera-e       58.0           7.3       150
# 1              Renault Kangoo Maxi ZE 33      31.0          22.4       130
# 2                           Nissan Leaf       36.0           7.9       144
# 3       Audi e-tron Sportback 55 quattro      86.5           5.7       200
# 4                 Porsche Taycan Turbo S      83.7           2.8       260
# ..                                   ...       ...           ...       ...
# 175                         MG Marvel R       65.0           7.9       200
# 176  Tesla Model 3 Long Range Dual Motor      76.0           4.4       233
# 177                 MG MG5 EV Long Range      57.0           7.7       185
# 178            Audi Q4 e-tron 45 quattro      76.6           6.9       180
# 179          Audi Q4 Sportback e-tron 40      76.6           8.5       160
#
#      Range  Efficiency  FastChargeSpeed              Drive  NumberofSeats  \
# 0      335         173              210  Front Wheel Drive              5
# 1      160         194                0  Front Wheel Drive              5
# 2      220         164              230  Front Wheel Drive              5
# 3      375         231              600    All Wheel Drive              5
# 4      390         215              860    All Wheel Drive              4
# ..     ...         ...              ...                ...            ...
# 175    340         191              390   Rear Wheel Drive              5
# 176    490         155              820    All Wheel Drive              5
# 177    340         168              340  Front Wheel Drive              5
# 178    385         199              470    All Wheel Drive              5
# 179    425         180              520   Rear Wheel Drive              5
#
#      PriceinGermany  PriceinUK Manufacturer
# 0             42990          0         Opel
# 1                 0      31680      Renault
# 2             29990      25995       Nissan
# 3                 0      79900         Audi
# 4            186336     138830      Porsche
# ..              ...        ...          ...
# 175           40000          0           MG
# 176           53560          0        Tesla
# 177               0      26495           MG
# 178           50900          0         Audi
# 179           49500          0         Audi
#
# [180 rows x 12 columns]

# %%
PriceinUK=[]
for item in df1['PriceinUK']:
    PriceinUK+=[int(item.replace('£','').replace(',',''))]
df1['PriceinUK']=PriceinUK
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 3
#       1 PriceinUK=[]
#       2 for item in df1['PriceinUK']:
# ----> 3     PriceinUK+=[int(item.replace('£','').replace(',',''))]
#       4 df1['PriceinUK']=PriceinUK
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
PriceinUK=[]
for item in df1['PriceinUK']:
    PriceinUK+=[int(item.replace('£','').replace(',',''))]
df1['PriceinUK']=PriceinUK
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 3
#       1 PriceinUK=[]
#       2 for item in df1['PriceinUK']:
# ----> 3     PriceinUK+=[int(item.replace('£','').replace(',',''))]
#       4 df1['PriceinUK']=PriceinUK
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
PriceinGermany=[]
for item in df1['PriceinGermany']:
    PriceinGermany+=[int(item.replace('€','').replace(',',''))]
df1['PriceinGermany']=PriceinGermany
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 3
#       1 PriceinGermany=[]
#       2 for item in df1['PriceinGermany']:
# ----> 3     PriceinGermany+=[int(item.replace('€','').replace(',',''))]
#       4 df1['PriceinGermany']=PriceinGermany
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
FastChargeSpeed=[]
for item in df1['FastChargeSpeed']:
    FastChargeSpeed+=[int(item.replace(' km/h','').replace('-','0'))]
df1['FastChargeSpeed']=FastChargeSpeed
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 3
#       1 FastChargeSpeed=[]
#       2 for item in df1['FastChargeSpeed']:
# ----> 3     FastChargeSpeed+=[int(item.replace(' km/h','').replace('-','0'))]
#       4 df1['FastChargeSpeed']=FastChargeSpeed
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
Efficiency=[]
for item in df1['Efficiency']:
    Efficiency+=[int(item.replace(' Wh/km',''))]
df1['Efficiency']=Efficiency
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 3
#       1 Efficiency=[]
#       2 for item in df1['Efficiency']:
# ----> 3     Efficiency+=[int(item.replace(' Wh/km',''))]
#       4 df1['Efficiency']=Efficiency
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
Range=[]
for item in df1['Range']:
    Range+=[int(item.replace(' km',''))]
df1['Range']=Range
TopSpeed=[]
for item in df1['TopSpeed']:
    TopSpeed+=[int(item.replace(' km/h',''))]
df1['TopSpeed']=TopSpeed
Acceleration=[]
for item in df1['Acceleration']:
    Acceleration+=[float(item.replace(' sec',''))]
df1['Acceleration']=Acceleration

# %%
Subtitle=[]
for item in df1['Subtitle']:
    Subtitle+=[float(item.replace('Battery Electric Vehicle | ','').replace(' kWh','').replace('      ',''))]
df1['Subtitle']=Subtitle

# %%
df1= df1.rename(columns = {'Subtitle':'KWH'})

# %%
df1.head()
# Out:
#                                Name   KWH  Acceleration  TopSpeed  Range  \
# 0                    Opel Ampera-e   58.0           7.3       150    335
# 1         Renault Kangoo Maxi ZE 33  31.0          22.4       130    160
# 2                      Nissan Leaf   36.0           7.9       144    220
# 3  Audi e-tron Sportback 55 quattro  86.5           5.7       200    375
# 4            Porsche Taycan Turbo S  83.7           2.8       260    390
#
#    Efficiency  FastChargeSpeed              Drive  NumberofSeats  \
# 0         173              210  Front Wheel Drive              5
# 1         194                0  Front Wheel Drive              5
# 2         164              230  Front Wheel Drive              5
# 3         231              600    All Wheel Drive              5
# 4         215              860    All Wheel Drive              4
#
#    PriceinGermany  PriceinUK Manufacturer
# 0           42990          0         Opel
# 1               0      31680      Renault
# 2           29990      25995       Nissan
# 3               0      79900         Audi
# 4          186336     138830      Porsche

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             180 non-null    object
#  1   KWH              180 non-null    float64
#  2   Acceleration     180 non-null    float64
#  3   TopSpeed         180 non-null    int64
#  4   Range            180 non-null    int64
#  5   Efficiency       180 non-null    int64
#  6   FastChargeSpeed  180 non-null    int64
#  7   Drive            180 non-null    object
#  8   NumberofSeats    180 non-null    int64
#  9   PriceinGermany   180 non-null    int64
#  10  PriceinUK        180 non-null    int64
#  11  Manufacturer     180 non-null    object
# dtypes: float64(2), int64(7), object(3)
# memory usage: 17.0+ KB

# %%
df1.corr()
# Out:
# C:\Users\kavan\AppData\Local\Temp\ipykernel_16544\473017434.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#                       KWH  Acceleration  TopSpeed     Range  Efficiency  \
# KWH              1.000000     -0.622985  0.691415  0.890092    0.356426
# Acceleration    -0.622985      1.000000 -0.821041 -0.712077    0.140984
# TopSpeed         0.691415     -0.821041  1.000000  0.760319   -0.047383
# Range            0.890092     -0.712077  0.760319  1.000000   -0.072273
# Efficiency       0.356426      0.140984 -0.047383 -0.072273    1.000000
# FastChargeSpeed  0.659743     -0.741670  0.773190  0.767574   -0.059914
# NumberofSeats    0.134447      0.318302 -0.242567 -0.068851    0.602469
# PriceinGermany   0.598084     -0.501519  0.678865  0.569037    0.239221
# PriceinUK        0.621253     -0.674273  0.792669  0.620757    0.084527
#
#                  FastChargeSpeed  NumberofSeats  PriceinGermany  PriceinUK
# KWH                     0.659743       0.134447        0.598084   0.621253
# Acceleration           -0.741670       0.318302       -0.501519  -0.674273
# TopSpeed                0.773190      -0.242567        0.678865   0.792669
# Range                   0.767574      -0.068851        0.569037   0.620757
# Efficiency             -0.059914       0.602469        0.239221   0.084527
# FastChargeSpeed         1.000000      -0.119644        0.595609   0.650851
# NumberofSeats          -0.119644       1.000000       -0.012455  -0.211985
# PriceinGermany          0.595609      -0.012455        1.000000   0.698753
# PriceinUK               0.650851      -0.211985        0.698753   1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df1.corr(),annot=True)
# Out:
# C:\Users\kavan\AppData\Local\Temp\ipykernel_16544\3288207558.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr(),annot=True)
# <Axes: >

# %%
sns.countplot(x = 'Drive', data = df1)
# Out:
# <Axes: xlabel='Drive', ylabel='count'>

# %%
sns.countplot(x = 'NumberofSeats', data = df1)
# Out:
# <Axes: xlabel='NumberofSeats', ylabel='count'>

# %%
plt.figure(figsize=(8,6))
sns.countplot(x = 'NumberofSeats', hue ='Drive', data = df1)
# Out:
# <Axes: xlabel='NumberofSeats', ylabel='count'>

# %%
plt.figure(figsize=(18,10))
sns.countplot(y = 'Manufacturer',  data = df1)
# Out:
# <Axes: xlabel='count', ylabel='Manufacturer'>

# %%
sns.relplot(x="Manufacturer", y="TopSpeed", height=6,hue="Drive",data=df1)

# %%
sns.relplot(x="Manufacturer", y="Acceleration", size="NumberofSeats", height=6,sizes=(15, 100),data=df1)

# %%
sns.relplot(x="TopSpeed", y="Range", height=6, hue="Drive",data=df1)

# %%
sns.jointplot(x=df1["Acceleration"], y = df1["Range"], kind="hex", color="#4CB391")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 sns.jointplot(x=df1["Acceleration"], y = df1["Range"], kind="hex", color="#4CB391")
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:2305, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2301     grid.plot_marginals(kdeplot, **marginal_kws)
#    2303 elif kind.startswith("hex"):
# -> 2305     x_bins = min(_freedman_diaconis_bins(grid.x), 50)
#    2306     y_bins = min(_freedman_diaconis_bins(grid.y), 50)
#    2307     gridsize = int(np.mean([x_bins, y_bins]))
#
# File ~\anaconda3\lib\site-packages\seaborn\distributions.py:2396, in _freedman_diaconis_bins(a)
#    2394 if len(a) < 2:
#    2395     return 1
# -> 2396 iqr = np.subtract.reduce(np.nanpercentile(a, [75, 25]))
#    2397 h = 2 * iqr / (len(a) ** (1 / 3))
#    2398 # fall back to sqrt(a) bins if iqr is 0
#
# File <__array_function__ internals>:180, in nanpercentile(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1384, in nanpercentile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    1382 if not function_base._quantile_is_valid(q):
#    1383     raise ValueError("Percentiles must be in the range [0, 100]")
# -> 1384 return _nanquantile_unchecked(
#    1385     a, q, axis, out, overwrite_input, method, keepdims)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1559, in _nanquantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    1557 if a.size == 0:
#    1558     return np.nanmean(a, axis, out=out, keepdims=keepdims)
# -> 1559 r, k = function_base._ureduce(a,
#    1560                               func=_nanquantile_ureduce_func,
#    1561                               q=q,
#    1562                               axis=axis,
#    1563                               out=out,
#    1564                               overwrite_input=overwrite_input,
#    1565                               method=method)
#    1566 if keepdims and keepdims is not np._NoValue:
#    1567     return r.reshape(q.shape + k)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\function_base.py:3725, in _ureduce(a, func, **kwargs)
#    3722 else:
#    3723     keepdim = (1,) * a.ndim
# -> 3725 r = func(a, **kwargs)
#    3726 return r, keepdim
#
# File ~\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1581, in _nanquantile_ureduce_func(a, q, axis, out, overwrite_input, method)
#    1579 if axis is None or a.ndim == 1:
#    1580     part = a.ravel()
# -> 1581     result = _nanquantile_1d(part, q, overwrite_input, method)
#    1582 else:
#    1583     result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
#    1584                                  overwrite_input, method)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1607, in _nanquantile_1d(arr1d, q, overwrite_input, method)
#    1603 if arr1d.size == 0:
#    1604     # convert to scalar
#    1605     return np.full(q.shape, np.nan, dtype=arr1d.dtype)[()]
# -> 1607 return function_base._quantile_unchecked(
#    1608     arr1d, q, overwrite_input=overwrite_input, method=method)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\function_base.py:4424, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    4416 def _quantile_unchecked(a,
#    4417                         q,
#    4418                         axis=None,
#    (...)
#    4421                         method="linear",
#    4422                         keepdims=False):
#    4423     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4424     r, k = _ureduce(a,
#    4425                     func=_quantile_ureduce_func,
#    4426                     q=q,
#    4427                     axis=axis,
#    4428                     out=out,
#    4429                     overwrite_input=overwrite_input,
#    4430                     method=method)
#    4431     if keepdims:
#    4432         return r.reshape(q.shape + k)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\function_base.py:3725, in _ureduce(a, func, **kwargs)
#    3722 else:
#    3723     keepdim = (1,) * a.ndim
# -> 3725 r = func(a, **kwargs)
#    3726 return r, keepdim
#
# File ~\anaconda3\lib\site-packages\numpy\lib\function_base.py:4593, in _quantile_ureduce_func(a, q, axis, out, overwrite_input, method)
#    4591     else:
#    4592         arr = a.copy()
# -> 4593 result = _quantile(arr,
#    4594                    quantiles=q,
#    4595                    axis=axis,
#    4596                    method=method,
#    4597                    out=out)
#    4598 return result
#
# File ~\anaconda3\lib\site-packages\numpy\lib\function_base.py:4710, in _quantile(arr, quantiles, axis, method, out)
#    4708     result_shape = virtual_indexes.shape + (1,) * (arr.ndim - 1)
#    4709     gamma = gamma.reshape(result_shape)
# -> 4710     result = _lerp(previous,
#    4711                    next,
#    4712                    gamma,
#    4713                    out=out)
#    4714 if np.any(slices_having_nans):
#    4715     if result.ndim == 0 and out is None:
#    4716         # can't write to a scalar
#
# File ~\anaconda3\lib\site-packages\numpy\lib\function_base.py:4527, in _lerp(a, b, t, out)
#    4513 def _lerp(a, b, t, out=None):
#    4514     """
#    4515     Compute the linear interpolation weighted by gamma on each point of
#    4516     two same shape array.
#    (...)
#    4525         Output array.
#    4526     """
# -> 4527     diff_b_a = subtract(b, a)
#    4528     # asanyarray is a stop-gap until gh-13105
#    4529     lerp_interpolation = asanyarray(add(a, diff_b_a * t, out=out))
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
sns.jointplot(x=df1["TopSpeed"], y=df1["Efficiency"], kind="hex", color="#4CB391")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 sns.jointplot(x=df1["TopSpeed"], y=df1["Efficiency"], kind="hex", color="#4CB391")
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:2305, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2301     grid.plot_marginals(kdeplot, **marginal_kws)
#    2303 elif kind.startswith("hex"):
# -> 2305     x_bins = min(_freedman_diaconis_bins(grid.x), 50)
#    2306     y_bins = min(_freedman_diaconis_bins(grid.y), 50)
#    2307     gridsize = int(np.mean([x_bins, y_bins]))
#
# File ~\anaconda3\lib\site-packages\seaborn\distributions.py:2396, in _freedman_diaconis_bins(a)
#    2394 if len(a) < 2:
#    2395     return 1
# -> 2396 iqr = np.subtract.reduce(np.nanpercentile(a, [75, 25]))
#    2397 h = 2 * iqr / (len(a) ** (1 / 3))
#    2398 # fall back to sqrt(a) bins if iqr is 0
#
# File <__array_function__ internals>:180, in nanpercentile(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1384, in nanpercentile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    1382 if not function_base._quantile_is_valid(q):
#    1383     raise ValueError("Percentiles must be in the range [0, 100]")
# -> 1384 return _nanquantile_unchecked(
#    1385     a, q, axis, out, overwrite_input, method, keepdims)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1559, in _nanquantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    1557 if a.size == 0:
#    1558     return np.nanmean(a, axis, out=out, keepdims=keepdims)
# -> 1559 r, k = function_base._ureduce(a,
#    1560                               func=_nanquantile_ureduce_func,
#    1561                               q=q,
#    1562                               axis=axis,
#    1563                               out=out,
#    1564                               overwrite_input=overwrite_input,
#    1565                               method=method)
#    1566 if keepdims and keepdims is not np._NoValue:
#    1567     return r.reshape(q.shape + k)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\function_base.py:3725, in _ureduce(a, func, **kwargs)
#    3722 else:
#    3723     keepdim = (1,) * a.ndim
# -> 3725 r = func(a, **kwargs)
#    3726 return r, keepdim
#
# File ~\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1581, in _nanquantile_ureduce_func(a, q, axis, out, overwrite_input, method)
#    1579 if axis is None or a.ndim == 1:
#    1580     part = a.ravel()
# -> 1581     result = _nanquantile_1d(part, q, overwrite_input, method)
#    1582 else:
#    1583     result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
#    1584                                  overwrite_input, method)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1607, in _nanquantile_1d(arr1d, q, overwrite_input, method)
#    1603 if arr1d.size == 0:
#    1604     # convert to scalar
#    1605     return np.full(q.shape, np.nan, dtype=arr1d.dtype)[()]
# -> 1607 return function_base._quantile_unchecked(
#    1608     arr1d, q, overwrite_input=overwrite_input, method=method)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\function_base.py:4424, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    4416 def _quantile_unchecked(a,
#    4417                         q,
#    4418                         axis=None,
#    (...)
#    4421                         method="linear",
#    4422                         keepdims=False):
#    4423     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4424     r, k = _ureduce(a,
#    4425                     func=_quantile_ureduce_func,
#    4426                     q=q,
#    4427                     axis=axis,
#    4428                     out=out,
#    4429                     overwrite_input=overwrite_input,
#    4430                     method=method)
#    4431     if keepdims:
#    4432         return r.reshape(q.shape + k)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\function_base.py:3725, in _ureduce(a, func, **kwargs)
#    3722 else:
#    3723     keepdim = (1,) * a.ndim
# -> 3725 r = func(a, **kwargs)
#    3726 return r, keepdim
#
# File ~\anaconda3\lib\site-packages\numpy\lib\function_base.py:4593, in _quantile_ureduce_func(a, q, axis, out, overwrite_input, method)
#    4591     else:
#    4592         arr = a.copy()
# -> 4593 result = _quantile(arr,
#    4594                    quantiles=q,
#    4595                    axis=axis,
#    4596                    method=method,
#    4597                    out=out)
#    4598 return result
#
# File ~\anaconda3\lib\site-packages\numpy\lib\function_base.py:4710, in _quantile(arr, quantiles, axis, method, out)
#    4708     result_shape = virtual_indexes.shape + (1,) * (arr.ndim - 1)
#    4709     gamma = gamma.reshape(result_shape)
# -> 4710     result = _lerp(previous,
#    4711                    next,
#    4712                    gamma,
#    4713                    out=out)
#    4714 if np.any(slices_having_nans):
#    4715     if result.ndim == 0 and out is None:
#    4716         # can't write to a scalar
#
# File ~\anaconda3\lib\site-packages\numpy\lib\function_base.py:4527, in _lerp(a, b, t, out)
#    4513 def _lerp(a, b, t, out=None):
#    4514     """
#    4515     Compute the linear interpolation weighted by gamma on each point of
#    4516     two same shape array.
#    (...)
#    4525         Output array.
#    4526     """
# -> 4527     diff_b_a = subtract(b, a)
#    4528     # asanyarray is a stop-gap until gh-13105
#    4529     lerp_interpolation = asanyarray(add(a, diff_b_a * t, out=out))
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
sns.relplot(x="FastChargeSpeed", y="Efficiency", height=6, data=df1)

# %%
c = 0
for i in range(0, len(df1["PriceinGermany"])):
    if(df1["PriceinGermany"][i]==0):
        c+=1
print('Empty Values:',c)
# Out:
# Empty Values: 0

# %%
df1.head()
# Out:
#                                Name  \
# 0                    Opel Ampera-e
# 1         Renault Kangoo Maxi ZE 33
# 2                      Nissan Leaf
# 3  Audi e-tron Sportback 55 quattro
# 4            Porsche Taycan Turbo S
#
#                                     Subtitle Acceleration  TopSpeed   Range  \
# 0   Battery Electric Vehicle |       58 kWh       7.3 sec  150 km/h  335 km
# 1   Battery Electric Vehicle |       31 kWh      22.4 sec  130 km/h  160 km
# 2   Battery Electric Vehicle |       36 kWh       7.9 sec  144 km/h  220 km
# 3  Battery Electric Vehicle |       86.5 kWh      5.7 sec  200 km/h  375 km
# 4  Battery Electric Vehicle |       83.7 kWh      2.8 sec  260 km/h  390 km
#
#   Efficiency FastChargeSpeed              Drive  NumberofSeats PriceinGermany  \
# 0  173 Wh/km        210 km/h  Front Wheel Drive              5        €42,990
# 1  194 Wh/km               -  Front Wheel Drive              5            NaN
# 2  164 Wh/km        230 km/h  Front Wheel Drive              5        €29,990
# 3  231 Wh/km        600 km/h    All Wheel Drive              5            NaN
# 4  215 Wh/km        860 km/h    All Wheel Drive              4       €186,336
#
#   PriceinUK Manufacturer
# 0       NaN         Opel
# 1   £31,680      Renault
# 2   £25,995       Nissan
# 3   £79,900         Audi
# 4  £138,830      Porsche

# %%
df1=df1.fillna('0')

# %%
df1.head()
# Out:
#                                Name  \
# 0                    Opel Ampera-e
# 1         Renault Kangoo Maxi ZE 33
# 2                      Nissan Leaf
# 3  Audi e-tron Sportback 55 quattro
# 4            Porsche Taycan Turbo S
#
#                                     Subtitle Acceleration  TopSpeed   Range  \
# 0   Battery Electric Vehicle |       58 kWh       7.3 sec  150 km/h  335 km
# 1   Battery Electric Vehicle |       31 kWh      22.4 sec  130 km/h  160 km
# 2   Battery Electric Vehicle |       36 kWh       7.9 sec  144 km/h  220 km
# 3  Battery Electric Vehicle |       86.5 kWh      5.7 sec  200 km/h  375 km
# 4  Battery Electric Vehicle |       83.7 kWh      2.8 sec  260 km/h  390 km
#
#   Efficiency FastChargeSpeed              Drive  NumberofSeats PriceinGermany  \
# 0  173 Wh/km        210 km/h  Front Wheel Drive              5        €42,990
# 1  194 Wh/km               -  Front Wheel Drive              5              0
# 2  164 Wh/km        230 km/h  Front Wheel Drive              5        €29,990
# 3  231 Wh/km        600 km/h    All Wheel Drive              5              0
# 4  215 Wh/km        860 km/h    All Wheel Drive              4       €186,336
#
#   PriceinUK Manufacturer
# 0         0         Opel
# 1   £31,680      Renault
# 2   £25,995       Nissan
# 3   £79,900         Audi
# 4  £138,830      Porsche

# %%
c=0
for i in range(0, len(df1["NumberofSeats"])):
    if (df1["NumberofSeats"][i]==7):
        c+=1
print('Empty Values:',c)
# Out:
# Empty Values: 32

# %%
c=0
for i in range(0, len(df1["PriceinGermany"])):
    if (df1["PriceinGermany"][i]==0):
        c+=1
print('Empty Values:',c)
# Out:
# Empty Values: 0

# %%
df1.head()
# Out:
#                                Name  \
# 0                    Opel Ampera-e
# 1         Renault Kangoo Maxi ZE 33
# 2                      Nissan Leaf
# 3  Audi e-tron Sportback 55 quattro
# 4            Porsche Taycan Turbo S
#
#                                     Subtitle Acceleration  TopSpeed   Range  \
# 0   Battery Electric Vehicle |       58 kWh       7.3 sec  150 km/h  335 km
# 1   Battery Electric Vehicle |       31 kWh      22.4 sec  130 km/h  160 km
# 2   Battery Electric Vehicle |       36 kWh       7.9 sec  144 km/h  220 km
# 3  Battery Electric Vehicle |       86.5 kWh      5.7 sec  200 km/h  375 km
# 4  Battery Electric Vehicle |       83.7 kWh      2.8 sec  260 km/h  390 km
#
#   Efficiency FastChargeSpeed              Drive  NumberofSeats PriceinGermany  \
# 0  173 Wh/km        210 km/h  Front Wheel Drive              5        €42,990
# 1  194 Wh/km               -  Front Wheel Drive              5              0
# 2  164 Wh/km        230 km/h  Front Wheel Drive              5        €29,990
# 3  231 Wh/km        600 km/h    All Wheel Drive              5              0
# 4  215 Wh/km        860 km/h    All Wheel Drive              4       €186,336
#
#   PriceinUK Manufacturer
# 0         0         Opel
# 1   £31,680      Renault
# 2   £25,995       Nissan
# 3   £79,900         Audi
# 4  £138,830      Porsche

# %%
df1["PriceinUK"].value_counts()
# Out:
# 0          44
# £48,000     3
# £45,000     3
# £79,900     2
# £31,500     2
#            ..
# £26,045     1
# £70,665     1
# £88,193     1
# £83,580     1
# £26,495     1
# Name: PriceinUK, Length: 124, dtype: int64
