# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
auto = pd.read_csv(r"C:\Users\kavan\OneDrive\Desktop\Automobile price data _Raw_.csv")

# %%
auto.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
auto.shape
# Out:
# (205, 26)

# %%
auto.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
auto.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
data = auto.replace('?',np.NAN)

# %%
data.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
temp = auto[auto['normalized-losses'] != '?']
column_mean = temp['normalized-losses'].astype(int).mean()
auto['normalized-losses'] = auto['normalized-losses'].replace('?',column_mean).astype(int)

# %%
auto.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
temp = auto[auto['price'] != '?']
column_mean = temp['price'].astype(int).mean()
auto['price'] = auto['price'].replace('?',column_mean).astype(int)

temp = auto[auto['horsepower'] != '?']
column_mean = temp['horsepower'].astype(int).mean()
auto['horsepower'] = auto['horsepower'].replace('?',column_mean).astype(int)

temp = auto[auto['peak-rpm'] != '?']
column_mean = temp['peak-rpm'].astype(int).mean()
auto['peak-rpm'] = auto['peak-rpm'].replace('?',column_mean).astype(int)

temp = auto[auto['bore'] != '?']
column_mean = temp['bore'].astype(float).mean()
auto['bore'] = auto['bore'].replace('?',column_mean).astype(float)

temp = auto[auto['stroke'] != '?']
column_mean = temp['stroke'].astype(float).mean()
auto['stroke'] = auto['stroke'].replace('?',column_mean).astype(float)

# %%
auto.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
auto['num-of-doors'] = auto['num-of-doors'].replace('?','four')

# %%
auto
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                122  alfa-romero       gas        std
# 1            3                122  alfa-romero       gas        std
# 2            1                122  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1                 95        volvo       gas        std
# 201         -1                 95        volvo       gas      turbo
# 202         -1                 95        volvo       gas        std
# 203         -1                 95        volvo    diesel      turbo
# 204         -1                 95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
auto.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         205.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          31.681008    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.300000   64.100000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000
# 75%      2.000000         137.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  205.000000  205.000000
# mean    53.724878  2555.565854   126.907317    3.329751    3.255423
# std      2.443522   520.680204    41.642693    0.270844    0.313597
# ...

# %% [markdown]
# # Univariate Analysis

# %%
auto[['engine-size','peak-rpm','curb-weight','horsepower','price','wheel-base']].hist(figsize=(10,8),bins=6)
plt.tight_layout()
plt.show()

# %%
plt.figure(1)
plt.subplot(221)
auto['engine-type'].value_counts(normalize=True).plot(figsize=(10,8),kind='bar',color='red')
plt.title("Number of Engine Type frequency diagram")
plt.ylabel('Number of Engine Type')
plt.xlabel('engine-type');

plt.subplot(222)
auto['num-of-doors'].value_counts(normalize=True).plot(figsize=(10,8),kind='bar',color='green')
plt.title("Number of Door frequency diagram")
plt.ylabel('Number of Doors')
plt.xlabel('num-of-doors');

plt.subplot(223)
auto['fuel-type'].value_counts(normalize= True).plot(figsize=(10,8),kind='bar',color='purple')
plt.title("Number of Fuel Type frequency diagram")
plt.ylabel('Number of vehicles')
plt.xlabel('fuel-type');

plt.subplot(224)
auto['body-style'].value_counts(normalize=True).plot(figsize=(10,8),kind='bar',color='orange')
plt.title("Number of Body Style frequency diagram")
plt.ylabel('Number of vehicles')
plt.xlabel('body-style');
plt.tight_layout()
plt.show()

# %%
plt.subplot(225)
auto['make'].value_counts(normalize=True).plot(figsize=(10,8),kind='bar',color='blue')
plt.title("Price based on the Vehicles Manufacturer")
plt.ylabel('price')
plt.xlabel('make');
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 plt.subplot(225)
#       2 auto['make'].value_counts(normalize=True).plot(figsize=(10,8),kind='bar',color='blue')
#       3 plt.title("Price based on the Vehicles Manufacturer")
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:1296, in subplot(*args, **kwargs)
#    1293 fig = gcf()
#    1295 # First, search for an existing subplot with a matching spec.
# -> 1296 key = SubplotSpec._from_subplot_args(fig, args)
#    1298 for ax in fig.axes:
#    1299     # if we found an Axes at the position sort out if we can re-use it
#    1300     if ax.get_subplotspec() == key:
#    1301         # if the user passed no kwargs, re-use
#
# File ~\anaconda3\lib\site-packages\matplotlib\gridspec.py:594, in SubplotSpec._from_subplot_args(figure, args)
#     592 else:
# ...

# %% [markdown]
# # Price based on Manufacturer

# %%
sns.catplot(data=auto, x="price", y="make",kind="bar")

# %% [markdown]
# # Price based on body style

# %%
sns.catplot(data=auto, x="price", y="body-style",kind="bar")

# %% [markdown]
# # Price based on fuel types

# %%
group = auto.groupby(['fuel-type'])['price'].sum()

# %%
group.plot.pie(figsize=(10,20), autopct="%.2f")
# Out:
# <Axes: ylabel='price'>

# %% [markdown]
# # Price based on fuel system

# %%
group = auto.groupby(['fuel-system'])['price'].sum()

# %%
group.plot.pie(figsize=(10,20), autopct="%.2f")
# Out:
# <Axes: ylabel='price'>

# %% [markdown]
# # Price based on Aspiration

# %%
sns.catplot(x='aspiration', y='price', data=auto, kind='box')

# %%
sns.catplot(x='fuel-type', y='price', data=auto, kind='box')

# %%
sns.catplot(x='fuel-system', y='price', data=auto, kind='box')

# %% [markdown]
# # Price based on engine size

# %%
sns.relplot(x='engine-size', y='price', data=auto, kind='line')

# %% [markdown]
# # Price based on Horsepower

# %%
sns.relplot(x='horsepower', y='price', data=auto, kind='line')

# %% [markdown]
# # Price based on drive wheels

# %%
plt.rcParams['figure.figsize']=(10,5)
ax = sns.boxplot(x="drive-wheels", y="price", data=auto)

# %%
import seaborn as sns
corr = auto.corr()
plt.figure(figsize=(20,9))
a = sns.heatmap(corr, annot = True, fmt='.2f')
# Out:
# C:\Users\kavan\AppData\Local\Temp\ipykernel_6904\639655117.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = auto.corr()

# %%
plt.rcParams['figure.figsize']=(23,10)
ax = sns.boxplot(x="make", y="price", data=auto)

# %%
plt.rcParams['figure.figsize']=(19,7)
ax = sns.boxplot(x="body-style", y="price", data = auto)

# %%
sns.catplot(data=auto, x="body-style", y="price", hue="aspiration", kind="point")

# %%
plt.rcParams['figure.figsize']=(10,5)
ax = sns.boxplot(x="drive-wheels", y="price", data=auto)

# %%
sns.catplot(data=auto, x="engine-type", y="engine-size", col="body-style",row="fuel-type")

# %%
sns.catplot(data=auto, y="normalized-losses", x="symboling" , hue="body-style" ,kind="point")

# %%
g = sns.pairplot(auto[["city-mpg", "horsepower", "engine-size", "curb-weight","price", "fuel-type"]], hue="fuel-type", diag_kind="hist")
